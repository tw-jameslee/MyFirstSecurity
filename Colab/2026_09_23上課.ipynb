# %% [markdown]
# <a href="https://colab.research.google.com/github/tw-jameslee/MyFirstSecurity/blob/main/Colab/2026_09_23%E4%B8%8A%E8%AA%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""程式設計進階選修課程(Python)
日期：2026/09/23
版本：v0.1
作者：李大仁
多媒體教材：https://twjames.pse.is/115python-video
"""

# %%
# 布林(Boolean)運算
# and or not

# python的資料型態有：整數(int)、字串(str)、浮點數(float)、布林(boolean)


a = 1
b = 2
c = 3

x = a>b
y = c>b
z =  a+b == c
p = c-a != b

print(x, y, z, p)
# Out:
# False True True False

# %%
s1 = "男"
m1 = "未婚"

s2 = "女"
m2 = "未婚"

s3 = "男"
m3 = "已婚"

s4 = "女"
m4 = "已婚"

# ------------------

p1 = (s1 == "女")  and  (m1 == "未婚")
print(p1, s1, m1)

p2 = (s2 == "女")  and  (m2 == "未婚")
print(p2, s2, m2)

p3 = (s3 == "女")  and  (m3 == "未婚")
print(p3, s3, m3)

p4 = (s4 == "女")  and  (m4 == "未婚")
print(p4, s4, m4)
# Out:
# False 男 未婚
# True 女 未婚
# False 男 已婚
# False 女 已婚

# %%
# 條件敘述
# if ... elif ... else

# input的結果會是字串，所以須要用int()轉換型別
age = int(  input("請輸入你的年紀：")  )

if age<18:
  print("你是未成年！")
  print("可以買半票")
else:
  print("你已成年！")
  print("需要買全票")
# Out:
# 請輸入你的年紀：15
# 你是未成年！
# 可以買半票

# %%
# input的結果會是字串，所以須要用int()轉換型別
age = int(  input("請輸入你的年紀：")  )

if age<8:
  print("你是未成年！")
  print("可以免買票")

elif age<18:
  print("你是未成年！")
  print("可以買半票")

elif age>=65:
  print("你是老人！")
  print("可以買6折票")

else:
  print("你已成年！")
  print("需要買全票")
# Out:
# 請輸入你的年紀：70
# 你是老人！
# 可以買6折票

# %%
# 迴圈：while ...
# 迴圈：for ...

x = int( input("請輸入一個正或負的整數：") )

while x != 0:

  if x>0:
    print(f"{x}是一個正數")
  else:
    print(f"{x}是一個負數")

  x = int( input("請輸入一個正或負的整數：") )

print("你輸入了0，程式結束")
# Out:
# 請輸入一個正或負的整數：12
# 12是一個正數
# 請輸入一個正或負的整數：-50
# -50是一個負數
# 請輸入一個正或負的整數：1
# 1是一個正數
# 請輸入一個正或負的整數：2
# 2是一個正數
# 請輸入一個正或負的整數：5
# 5是一個正數
# 請輸入一個正或負的整數：100
# 100是一個正數
# 請輸入一個正或負的整數：-3000
# -3000是一個負數
# 請輸入一個正或負的整數：0
# 你輸入了0，程式結束

# %%
# 作業一：終極密碼

# 由電腦自動產生一個整(1~100)
# 請使用者去猜，然後由程式告訴使用者太大、太小、猜對了

import random

# 先由電腦產生答案ans
ans = random.randint(1, 100)
print(f"答案是: {ans}")

g = int( input("請猜一個數字(1~100)：") )
while g != ans:  # 如果猜的和答案不同
  if ans>g:
    print("大一點！")
  else:
    print("小一點！")

  g = int( input("請猜一個數字(1~100)：") )

print("恭喜你，猜對了！")
# Out:
# 答案是: 94
# 請猜一個數字(1~100)：50
# 大一點！
# 請猜一個數字(1~100)：80
# 大一點！
# 請猜一個數字(1~100)：90
# 大一點！
# 請猜一個數字(1~100)：95
# 小一點！
# 請猜一個數字(1~100)：93
# 大一點！
# 請猜一個數字(1~100)：94
# 恭喜你，猜對了！
